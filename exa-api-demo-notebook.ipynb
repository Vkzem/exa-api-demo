# %%
# Import OS module to provide Exa API key as an environment variable
import os

# Set the Exa API key - find yours in your Exa dashboard overview
os.environ["EXA_API_KEY"] = "1352d7b3-ca52-4171-a515-7721fed66353"

# %%
# If required, install the exa_py module
# %pip install exa_py

# Import the Exa SDK
from exa_py import Exa

# Create an Exa object
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: c:\Users\VK\.pyenv\pyenv-win\versions\3.10.11\python.exe -m pip install --upgrade pip

# %%
# pip install exa_py
from exa_py import Exa
exa = Exa("1352d7b3-ca52-4171-a515-7721fed66353")

response = exa.search_and_contents(
  "Most recent common law cases in Australia covering Australian Consumer Law statutes Section 18",
  num_results=10,
  use_autoprompt=True,
  highlights={"num_sentences": 3, },
)

print(response)
# Out:
# Title: Edwards v Caravan & RV Central Pty Ltd
# URL: https://www.caselaw.nsw.gov.au/decision/17fa9dfbeb25637e34a96202
# ID: https://www.caselaw.nsw.gov.au/decision/17fa9dfbeb25637e34a96202
# Score: 0.19082966446876526
# Published Date: 2016-04-11
# Author: None
# Text: None
# Highlights: ['(f) an order that requires a respondent to return to the claimant specified goods which are in the possession or under the control of that respondent, whether the property in the goods has passed or not, (g) an order that requires a respondent to replace goods to which the claim relates, (h) an order that requires a respondent to refund all or part of the purchase price of specified goods that are in the possession (or under the control) of the claimant and the claimant to return all or part of those goods to the respondent (whether the property in the goods has passed or not).']
# Highlight Scores: [0.31947967410087585]
#
#
# ...
